# %% [markdown]
# Architecture pilot: LocationService Result pattern and client-safe design.

# %% [markdown]
# Anteckning: Fixa meddelandeflödet (conversations/messages) och alinera Supabase-klienter.

# %% [markdown]
# Framtida uppgift vid produktionssättning: Lägg till e-postnotiser för nya meddelanden + inställning i profilsidan för att styra notiser (on/off, ev. frekvens).
